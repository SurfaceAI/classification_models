# %%
import pandas as pd
from sklearn.metrics import precision_score, recall_score
import os
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /var/folders/zg/ds4nwmvx3kq28hn4r4zwbbw80000gp/T/ipykernel_1471/3244023466.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
ds_version = "road_scenery_experiment"
root_data_path = os.path.join("..", "data", ds_version)
data_path = os.path.join(root_data_path, "metadata")

# %%
# focus only
file_name = "effnet_scenery_prediction-road_scenery-20241030_145354.csv"

# focus and no focus
file_name_no_focus_incl = "effnet_scenery_prediction-road_scenery-20240917_153147.csv"

# %%
pred = pd.DataFrame()
# surface = file_name.split("_")[0]
print(f"reading {file_name}")
df = pd.read_csv(os.path.join(data_path, file_name))
# df["surface_pred"] = surface
pred = pd.concat([pred, df])

pred.rename(columns={"Image": "image_id", "Prediction": "scenery_probability", "Level_0": "scenery_label_pred"}, inplace=True)
# Out:
# reading effnet_scenery_prediction-road_scenery-20241030_145354.csv

# %%
pred
# Out:
#                image_id  scenery_probability    Level  \
# 0      1002484893825364             0.999971  scenery
# 1      1002484893825364             0.000008  scenery
# 2      1002484893825364             0.000002  scenery
# 3      1002484893825364             0.000002  scenery
# 4      1002484893825364             0.000010  scenery
# ...                 ...                  ...      ...
# 51263   988054072097833             0.000251  scenery
# 51264   988054072097833             0.000036  scenery
# 51265   988054072097833             0.020240  scenery
# 51266   988054072097833             0.000098  scenery
# 51267   988054072097833             0.968952  scenery
#
#                          scenery_label_pred  is_in_validation
# 0               1_1_road__1_1_rails_on_road                 0
# 1                1_1_road__1_1_road_general                 0
# 2                 1_2_bicycle__1_2_cycleway                 0
# 3                     1_2_bicycle__1_2_lane                 0
# 4               1_3_pedestrian__1_3_footway                 0
# ...                                     ...               ...
# 51263             1_2_bicycle__1_2_cycleway                 0
# 51264                 1_2_bicycle__1_2_lane                 0
# 51265           1_3_pedestrian__1_3_footway                 0
# 51266  1_3_pedestrian__1_3_railway_platform                 0
# 51267        1_4_path__1_4_path_unspecified                 0
#
# [51268 rows x 5 columns]

# %%
# the prediction holds a value for each surface and a class probability. Only keep the highest prob.
idx = pred.groupby("image_id")["scenery_probability"].idxmax()
pred = pred.loc[idx]
pred
# Out:
#                 image_id  scenery_probability    Level  \
# 19882    102491565788586             0.999730  scenery
# 23657    103194292097226             0.996220  scenery
# 652      103629748692983             0.955223  scenery
# 22641    105366992004127             0.995017  scenery
# 750      106106185328228             0.997763  scenery
# ...                  ...                  ...      ...
# 17102   7689494587769097             0.999903  scenery
# 42153   8336520079756359             0.999851  scenery
# 18614   8816216721736969             0.996421  scenery
# 18859   9101355396601639             0.999319  scenery
# 32346  24272315469049348             0.998280  scenery
#
#                    scenery_label_pred  is_in_validation
# 19882       1_2_bicycle__1_2_cycleway                 0
# 23657     1_3_pedestrian__1_3_footway                 0
# 652        1_1_road__1_1_road_general                 0
# 22641           1_2_bicycle__1_2_lane                 0
# 750        1_1_road__1_1_road_general                 0
# ...                               ...               ...
# 17102      1_1_road__1_1_road_general                 0
# 42153  1_4_path__1_4_path_unspecified                 0
# 18614      1_1_road__1_1_road_general                 0
# 18859      1_1_road__1_1_road_general                 0
# 32346  1_4_path__1_4_path_unspecified                 0
#
# [7324 rows x 5 columns]

# %%
annot = pd.read_csv(os.path.join(data_path, "annotations_scenery_v4.csv"))
annot.rename(columns={"road_scenery": "scenery_label_true"}, inplace=True)

# %%
no_focus_valid = pd.read_csv(os.path.join(data_path, file_name_no_focus_incl))
no_focus_valid.rename(columns={"Image": "image_id", "Prediction": "scenery_probability", "Level_0": "scenery_label_pred"}, inplace=True)
idx = no_focus_valid.groupby("image_id")["scenery_probability"].idxmax()
no_focus_valid = no_focus_valid.loc[idx]
no_focus_valid = no_focus_valid.set_index("image_id").join(annot[["image_id", "scenery_label_true"]].set_index("image_id", inplace=False), how="left")
no_focus_valid
# Out:
#                    scenery_probability    Level  \
# image_id
# 102491565788586               0.999741  scenery
# 103194292097226               0.997843  scenery
# 103629748692983               0.709661  scenery
# 105366992004127               0.999957  scenery
# 106106185328228               0.990818  scenery
# ...                                ...      ...
# 7689494587769097              0.999780  scenery
# 8336520079756359              0.999787  scenery
# 8816216721736969              0.994679  scenery
# 9101355396601639              0.896543  scenery
# 24272315469049348             0.999790  scenery
#
#                                scenery_label_pred  is_in_validation  \
# image_id
# 102491565788586         1_2_bicycle__1_2_cycleway                 0
# 103194292097226       1_3_pedestrian__1_3_footway                 0
# 103629748692983        1_1_road__1_1_road_general                 0
# 105366992004127             1_2_bicycle__1_2_lane                 0
# 106106185328228        1_1_road__1_1_road_general                 0
# ...                                           ...               ...
# 7689494587769097       1_1_road__1_1_road_general                 0
# 8336520079756359   1_4_path__1_4_path_unspecified                 0
# 8816216721736969       1_1_road__1_1_road_general                 0
# 9101355396601639       1_1_road__1_1_road_general                 0
# 24272315469049348  1_4_path__1_4_path_unspecified                 0
#
#                                scenery_label_true
# image_id
# 102491565788586         1_2_bicycle__1_2_cycleway
# 103194292097226       1_3_pedestrian__1_3_footway
# 103629748692983        1_1_road__1_1_road_general
# 105366992004127             1_2_bicycle__1_2_lane
# 106106185328228        1_1_road__1_1_road_general
# ...                                           ...
# 7689494587769097       1_1_road__1_1_road_general
# 8336520079756359   1_4_path__1_4_path_unspecified
# 8816216721736969       1_1_road__1_1_road_general
# 9101355396601639       1_1_road__1_1_road_general
# 24272315469049348  1_4_path__1_4_path_unspecified
#
# [7324 rows x 5 columns]

# %%
df = pred.set_index("image_id").join(annot[["image_id", "scenery_label_true"]].set_index("image_id"), how="left")
df
# Out:
#                    scenery_probability    Level  \
# image_id
# 102491565788586               0.999730  scenery
# 103194292097226               0.996220  scenery
# 103629748692983               0.955223  scenery
# 105366992004127               0.995017  scenery
# 106106185328228               0.997763  scenery
# ...                                ...      ...
# 7689494587769097              0.999903  scenery
# 8336520079756359              0.999851  scenery
# 8816216721736969              0.996421  scenery
# 9101355396601639              0.999319  scenery
# 24272315469049348             0.998280  scenery
#
#                                scenery_label_pred  is_in_validation  \
# image_id
# 102491565788586         1_2_bicycle__1_2_cycleway                 0
# 103194292097226       1_3_pedestrian__1_3_footway                 0
# 103629748692983        1_1_road__1_1_road_general                 0
# 105366992004127             1_2_bicycle__1_2_lane                 0
# 106106185328228        1_1_road__1_1_road_general                 0
# ...                                           ...               ...
# 7689494587769097       1_1_road__1_1_road_general                 0
# 8336520079756359   1_4_path__1_4_path_unspecified                 0
# 8816216721736969       1_1_road__1_1_road_general                 0
# 9101355396601639       1_1_road__1_1_road_general                 0
# 24272315469049348  1_4_path__1_4_path_unspecified                 0
#
#                                scenery_label_true
# image_id
# 102491565788586         1_2_bicycle__1_2_cycleway
# 103194292097226       1_3_pedestrian__1_3_footway
# 103629748692983        1_1_road__1_1_road_general
# 105366992004127             1_2_bicycle__1_2_lane
# 106106185328228        1_1_road__1_1_road_general
# ...                                           ...
# 7689494587769097       1_1_road__1_1_road_general
# 8336520079756359   1_4_path__1_4_path_unspecified
# 8816216721736969       1_1_road__1_1_road_general
# 9101355396601639       1_1_road__1_1_road_general
# 24272315469049348  1_4_path__1_4_path_unspecified
#
# [7324 rows x 5 columns]

# %%
# exclude not recognizable
# df = df[df.surface_true.notna()]

# %%
df.groupby(["image_id"]).size().sort_values(ascending=False)
# Out:
# image_id
# 102491565788586      1
# 905554453347173      1
# 905026576721177      1
# 904567290106055      1
# 904411440414657      1
#                     ..
# 435499201815990      1
# 434653685584013      1
# 434338691315035      1
# 432360655166346      1
# 24272315469049348    1
# Length: 7324, dtype: int64

# %%
df.groupby(["scenery_label_true"]).size()
# Out:
# scenery_label_true
# 1_1_road__1_1_rails_on_road               56
# 1_1_road__1_1_road_general              2776
# 1_2_bicycle__1_2_cycleway                401
# 1_2_bicycle__1_2_lane                    144
# 1_3_pedestrian__1_3_footway              447
# 1_3_pedestrian__1_3_railway_platform      17
# 1_4_path__1_4_path_unspecified          2397
# 2_1_no_focus_no_street__2_1_all         1086
# dtype: int64

# %%
df.groupby(["is_in_validation", "scenery_label_true"]).size()
# Out:
# is_in_validation  scenery_label_true
# 0                 1_1_road__1_1_rails_on_road               45
#                   1_1_road__1_1_road_general              2221
#                   1_2_bicycle__1_2_cycleway                321
#                   1_2_bicycle__1_2_lane                    115
#                   1_3_pedestrian__1_3_footway              357
#                   1_3_pedestrian__1_3_railway_platform      14
#                   1_4_path__1_4_path_unspecified          1917
#                   2_1_no_focus_no_street__2_1_all         1086
# 1                 1_1_road__1_1_rails_on_road               11
#                   1_1_road__1_1_road_general               555
#                   1_2_bicycle__1_2_cycleway                 80
#                   1_2_bicycle__1_2_lane                     29
#                   1_3_pedestrian__1_3_footway               90
#                   1_3_pedestrian__1_3_railway_platform       3
#                   1_4_path__1_4_path_unspecified           480
# dtype: int64

# %%
# add images for no focus no street class to simulate same validation size as scenery with no focus no street included

df.loc[no_focus_valid.index[no_focus_valid.is_in_validation == 1], 'is_in_validation'] = 1
df.groupby(["is_in_validation", "scenery_label_true"]).size()
# Out:
# is_in_validation  scenery_label_true
# 0                 1_1_road__1_1_rails_on_road               45
#                   1_1_road__1_1_road_general              2221
#                   1_2_bicycle__1_2_cycleway                321
#                   1_2_bicycle__1_2_lane                    115
#                   1_3_pedestrian__1_3_footway              357
#                   1_3_pedestrian__1_3_railway_platform      14
#                   1_4_path__1_4_path_unspecified          1917
#                   2_1_no_focus_no_street__2_1_all          869
# 1                 1_1_road__1_1_rails_on_road               11
#                   1_1_road__1_1_road_general               555
#                   1_2_bicycle__1_2_cycleway                 80
#                   1_2_bicycle__1_2_lane                     29
#                   1_3_pedestrian__1_3_footway               90
#                   1_3_pedestrian__1_3_railway_platform       3
#                   1_4_path__1_4_path_unspecified           480
#                   2_1_no_focus_no_street__2_1_all          217
# dtype: int64

# %%
# df_focus = df[df.scenery_label_true != "2_1_no_focus_no_street__2_1_all"]
# df_no_focus = df[df.scenery_label_true == "2_1_no_focus_no_street__2_1_all"]
df_valid = df[df.is_in_validation == 1]
df_train = df[df.is_in_validation == 0]

# %%
df_train.groupby(["scenery_label_true"]).size()
# Out:
# scenery_label_true
# 1_1_road__1_1_rails_on_road               45
# 1_1_road__1_1_road_general              2221
# 1_2_bicycle__1_2_cycleway                321
# 1_2_bicycle__1_2_lane                    115
# 1_3_pedestrian__1_3_footway              357
# 1_3_pedestrian__1_3_railway_platform      14
# 1_4_path__1_4_path_unspecified          1917
# 2_1_no_focus_no_street__2_1_all          869
# dtype: int64

# %%
# df.groupby(["is_in_validation", "scenery_label_true"]).size().to_csv("test.csv")

# %% [markdown]
# ## Global measures

# %%
def compute_measures(true_label, pred_label):
    m = {
    "accuracy": sum(true_label == pred_label) / len(true_label),
    # "correlation": np.corrcoef(true_float, pred_float)[0, 1],
    # "r_square": r2_score(true_float, pred_float),
    # "mse": mean_squared_error(true_float, pred_float)
    }
    # m["rmse"] = np.sqrt(m["mse"])
    return m

# %%
# all
gm = compute_measures(df.scenery_label_true, df.scenery_label_pred)
gm_valid = compute_measures(df_valid.scenery_label_true, df_valid.scenery_label_pred)
gm_train = compute_measures(df_train.scenery_label_true, df_train.scenery_label_pred)
pd.concat([pd.Series(gm, name="all"), pd.Series(gm_valid, name="validation"), pd.Series(gm_train, name="train")], axis=1).round(2)
# Out:
#            all  validation  train
# accuracy  0.83        0.79   0.84

# %%
from sklearn.metrics import classification_report

report = classification_report(df_train.scenery_label_true, df_train.scenery_label_pred)
print(report)
# Out:
#                                       precision    recall  f1-score   support
#
#          1_1_road__1_1_rails_on_road       0.79      1.00      0.88        45
#           1_1_road__1_1_road_general       0.88      0.99      0.93      2221
#            1_2_bicycle__1_2_cycleway       0.90      1.00      0.95       321
#                1_2_bicycle__1_2_lane       0.85      1.00      0.92       115
#          1_3_pedestrian__1_3_footway       0.80      0.99      0.89       357
# 1_3_pedestrian__1_3_railway_platform       0.47      1.00      0.64        14
#       1_4_path__1_4_path_unspecified       0.81      0.99      0.89      1917
#      2_1_no_focus_no_street__2_1_all       0.00      0.00      0.00       869
#
#                             accuracy                           0.84      5859
#                            macro avg       0.69      0.87      0.76      5859
#                         weighted avg       0.72      0.84      0.78      5859
# /Users/edith/git/SurfaceAI/classification_models/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/edith/git/SurfaceAI/classification_models/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/edith/git/SurfaceAI/classification_models/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Measures by surface class

# %%
# all
# gm_surface = pd.DataFrame()
# for surface in df.surface_true.unique():
#     df_ = df[df.surface_true == surface]
#     gm = compute_measures(df_.quality_float_true, df_.quality_float_pred)
#     gm_surface = pd.concat([gm_surface, pd.Series(gm, name=surface)], axis=1)

# gm_surface.round(2)

# %%
# all
# gm_surface = pd.DataFrame()
# for surface in df.surface_true.unique():
#     df_ = df[df.surface_true == surface]
#     gm = compute_measures(df_.quality_float_true, df_.quality_float_pred)
#     gm_surface = pd.concat([gm_surface, pd.Series(gm, name=surface)], axis=1)

# gm_surface.round(2)

# %%
# only validation
# gm_surface = pd.DataFrame()
# for surface in df_valid.surface_true.unique():
#     df_ = df_valid[df_valid.surface_true == surface]
#     gm = compute_measures(df_.quality_float_true, df_.quality_float_pred)
#     gm_surface = pd.concat([gm_surface, pd.Series(gm, name=surface)], axis=1)

# gm_surface.round(2)

# %% [markdown]
# ## compare float values

# %%
df = df_valid
# df = df_train
df
# Out:
#                   scenery_probability    Level  \
# image_id
# 109544924542566              0.548518  scenery
# 109564885090094              0.994261  scenery
# 112575114875540              0.999045  scenery
# 114964257602270              0.995620  scenery
# 115256483951405              0.981663  scenery
# ...                               ...      ...
# 6266054923461896             0.553209  scenery
# 6321034651344484             0.999259  scenery
# 6414820121948480             0.998631  scenery
# 6721946177838599             0.871405  scenery
# 7093003020741208             0.999742  scenery
#
#                               scenery_label_pred  is_in_validation  \
# image_id
# 109544924542566   1_4_path__1_4_path_unspecified                 1
# 109564885090094   1_4_path__1_4_path_unspecified                 1
# 112575114875540       1_1_road__1_1_road_general                 1
# 114964257602270       1_1_road__1_1_road_general                 1
# 115256483951405      1_3_pedestrian__1_3_footway                 1
# ...                                          ...               ...
# 6266054923461896  1_4_path__1_4_path_unspecified                 1
# 6321034651344484  1_4_path__1_4_path_unspecified                 1
# 6414820121948480  1_4_path__1_4_path_unspecified                 1
# 6721946177838599       1_2_bicycle__1_2_cycleway                 1
# 7093003020741208      1_1_road__1_1_road_general                 1
#
#                                scenery_label_true
# image_id
# 109544924542566        1_1_road__1_1_road_general
# 109564885090094    1_4_path__1_4_path_unspecified
# 112575114875540        1_1_road__1_1_road_general
# 114964257602270   2_1_no_focus_no_street__2_1_all
# 115256483951405       1_3_pedestrian__1_3_footway
# ...                                           ...
# 6266054923461896   1_4_path__1_4_path_unspecified
# 6321034651344484   1_4_path__1_4_path_unspecified
# 6414820121948480   1_4_path__1_4_path_unspecified
# 6721946177838599  2_1_no_focus_no_street__2_1_all
# 7093003020741208       1_1_road__1_1_road_general
#
# [1465 rows x 5 columns]

# %%
# Plot
# np.random.seed(5)
# colors = {surface_type: np.random.rand(3,) for surface_type in df.surface_true.unique()}

# sns.scatterplot(data=df, x="quality_float_true", y="quality_float_pred", hue="surface_true", palette=colors, legend="full")
# plt.xlabel('True')
# plt.ylabel('Pred')
# plt.title('True vs. Pred quality by surface')
# plt.show()

# %%
# sns.set_style("whitegrid")

# # Create a FacetGrid
# g = sns.FacetGrid(df, col="surface_true", col_wrap=3)

# # Map scatter plot for each surface type
# g.map(sns.scatterplot, "quality_float_true", "quality_float_pred")

# plt.show()

# %% [markdown]
# #### Hom much do the deviate?

# %%
# df["deviation"] = df.quality_float_true - df.quality_float_pred

# %% [markdown]
# **Overall**

# %%
# df.deviation.hist(bins=20)

# %% [markdown]
# **by surface**

# %%
# # Create a FacetGrid for histograms
# g_hist = sns.FacetGrid(df, col="surface_true", col_wrap=3)

# # Map histogram for deviation for each surface type
# g_hist.map(plt.hist, "deviation", color='green', density=True, bins=20)

# plt.show()

# %% [markdown]
# ## compare classes

# %%
selected_classes = {
        '1_1_road': [
            '1_1_rails_on_road',
            '1_1_road_general',
        ],
        '1_2_bicycle': [
            '1_2_cycleway',
            '1_2_lane',
        ],
        '1_3_pedestrian': [
            # '1_3_pedestrian_area',
            '1_3_railway_platform',
            '1_3_footway',
        ],
        '1_4_path': [
            '1_4_path_unspecified',
        ],
        '2_1_no_focus_no_street': [
            '2_1_all'
        ],
    }

valid_labels = []
for key, values in selected_classes.items():
    for value in values:
        label = key + '__' + value
        valid_labels.append(label)

# %%
# Plotting the confusion matrix using seaborn heatmap

cm = confusion_matrix(df.scenery_label_true, df.scenery_label_pred, labels=valid_labels)
plt.figure()
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=valid_labels,
            yticklabels=valid_labels)
plt.title(f"Confusion Matrix for Scenery")
plt.xlabel("Predicted")
plt.ylabel("Annotated")
plt.show()

# %%
df[df.scenery_label_true.isin(valid_labels)]
# Out:
#                   scenery_probability    Level  \
# image_id
# 109544924542566              0.548518  scenery
# 109564885090094              0.994261  scenery
# 112575114875540              0.999045  scenery
# 114964257602270              0.995620  scenery
# 115256483951405              0.981663  scenery
# ...                               ...      ...
# 6266054923461896             0.553209  scenery
# 6321034651344484             0.999259  scenery
# 6414820121948480             0.998631  scenery
# 6721946177838599             0.871405  scenery
# 7093003020741208             0.999742  scenery
#
#                               scenery_label_pred  is_in_validation  \
# image_id
# 109544924542566   1_4_path__1_4_path_unspecified                 1
# 109564885090094   1_4_path__1_4_path_unspecified                 1
# 112575114875540       1_1_road__1_1_road_general                 1
# 114964257602270       1_1_road__1_1_road_general                 1
# 115256483951405      1_3_pedestrian__1_3_footway                 1
# ...                                          ...               ...
# 6266054923461896  1_4_path__1_4_path_unspecified                 1
# 6321034651344484  1_4_path__1_4_path_unspecified                 1
# 6414820121948480  1_4_path__1_4_path_unspecified                 1
# 6721946177838599       1_2_bicycle__1_2_cycleway                 1
# 7093003020741208      1_1_road__1_1_road_general                 1
#
#                                scenery_label_true
# image_id
# 109544924542566        1_1_road__1_1_road_general
# 109564885090094    1_4_path__1_4_path_unspecified
# 112575114875540        1_1_road__1_1_road_general
# 114964257602270   2_1_no_focus_no_street__2_1_all
# 115256483951405       1_3_pedestrian__1_3_footway
# ...                                           ...
# 6266054923461896   1_4_path__1_4_path_unspecified
# 6321034651344484   1_4_path__1_4_path_unspecified
# 6414820121948480   1_4_path__1_4_path_unspecified
# 6721946177838599  2_1_no_focus_no_street__2_1_all
# 7093003020741208       1_1_road__1_1_road_general
#
# [1465 rows x 5 columns]

# %%
# Extract predicted and ground truth values

class_precision = precision_score(df[df.scenery_label_true.isin(valid_labels)].scenery_label_true, df[df.scenery_label_true.isin(valid_labels)].scenery_label_pred, average='weighted')
class_recall = recall_score(df[df.scenery_label_true.isin(valid_labels)].scenery_label_true, df[df.scenery_label_true.isin(valid_labels)].scenery_label_pred, average='weighted')

print(f"Count: {len(df)}")
print(f"Precision: {round(class_precision, 2)}")
print(f"Recall: {round(class_recall, 2)}")
print("------------------------")
# Out:
# Count: 1465
# Precision: 0.67
# Recall: 0.79
# ------------------------
# /Users/edith/git/SurfaceAI/classification_models/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import classification_report

report = classification_report(df[df.scenery_label_true.isin(valid_labels)].scenery_label_true, df[df.scenery_label_true.isin(valid_labels)].scenery_label_pred)
print(report)
# Out:
#                                       precision    recall  f1-score   support
#
#          1_1_road__1_1_rails_on_road       0.67      0.73      0.70        11
#           1_1_road__1_1_road_general       0.86      0.97      0.91       555
#            1_2_bicycle__1_2_cycleway       0.75      0.81      0.78        80
#                1_2_bicycle__1_2_lane       0.84      0.90      0.87        29
#          1_3_pedestrian__1_3_footway       0.60      0.61      0.60        90
# 1_3_pedestrian__1_3_railway_platform       0.38      1.00      0.55         3
#       1_4_path__1_4_path_unspecified       0.75      0.96      0.84       480
#      2_1_no_focus_no_street__2_1_all       0.00      0.00      0.00       217
#
#                             accuracy                           0.79      1465
#                            macro avg       0.60      0.75      0.66      1465
#                         weighted avg       0.67      0.79      0.73      1465
# /Users/edith/git/SurfaceAI/classification_models/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/edith/git/SurfaceAI/classification_models/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/edith/git/SurfaceAI/classification_models/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# all images that were incorrectly classified
misclassification = df[(df.scenery_label_pred != df.scenery_label_true) & (df.is_in_validation == 1)]

# %%
misclassification = misclassification.sort_values("image_id")
misclassification.reset_index( inplace=True)
misclassification[["image_id", "is_in_validation", "scenery_probability",
                   "scenery_label_true", "scenery_label_pred"]
                   ].to_csv(os.path.join(data_path, "misclassification_scenery_v4.csv"), index=False)

# %%
# store missclassified images in folder
import shutil

path = os.path.join(root_data_path, "misclassified_images", "valid_dataset")
folder_list = ["classified_images","classified_images_add_on", "classified_images_add_on_b", "classified_images_add_on_c"]
os.makedirs(path, exist_ok=True)
for i in range(len(misclassification)):  # len(misclassification)
    is_found = False
    img = misclassification.loc[i]
    destination_folder_path = os.path.join(path, img.scenery_label_true, img.scenery_label_pred)
    os.makedirs(destination_folder_path, exist_ok=True)
    destination_path = os.path.join(destination_folder_path, f"{img.image_id}.jpg")
    folders = img.scenery_label_true.split("__")
    for folder in folder_list:
        img_path = os.path.join(root_data_path, folder)
        image_filename = os.path.join(img_path, folders[0], folders[1], f"{img.image_id}.jpg")
        if os.path.exists(image_filename):
            is_found = True
            shutil.copy(image_filename, destination_folder_path)
            break
    if not is_found:
        print(f"{img.image_id} not found.")
# Out:
# 200667111667467 not found.
# 296024502118434 not found.
# 709098773461112 not found.
# 933492844633072 not found.
# 5189827941103180 not found.

# %%
# store missclassified images in folder
# path = "/Users/alexandra/Nextcloud-HTW/SHARED/SurfaceAI/data/mapillary_images/training/V4/metadata/model_predictions/VGG16_V4_not_annotated/missclassified_wo_nostreet"
# os.makedirs(path, exist_ok=True)
# for image_id in misclassification_wo_nostreet.index:
#     destination_path = os.path.join(path, f"{image_id}.jpg")
#     image_filename = os.path.join("/Users/alexandra/Nextcloud-HTW/SHARED/SurfaceAI/data/mapillary_images/training/V4/unsorted_images", f"{image_id}.jpg")
#     shutil.copy(image_filename, destination_path)

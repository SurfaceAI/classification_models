# %%
import pandas as pd
from sklearn.metrics import precision_score, recall_score
import os
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score, confusion_matrix, mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap
from scipy import stats

# %%
ds_version_1 = "V1_0"
data_path_1 = os.path.join("..", "data", ds_version_1, "metadata")

ds_version_2 = "RTK"
data_path_2 = os.path.join("..", "data", ds_version_2, "metadata")

# %%
#define F-test function for variance test
def f_test(x, y):
    x = np.array(x)
    y = np.array(y)
    f = np.var(x, ddof=1)/np.var(y, ddof=1) #calculate F test statistic 
    dfn = x.size-1 #define degrees of freedom numerator 
    dfd = y.size-1 #define degrees of freedom denominator 
    p = 1-stats.f.cdf(f, dfn, dfd) #find p-value of F test statistic 
    return f, p

# %% [markdown]
# # Correlation

# %%
report_1 = pd.read_csv(os.path.join(data_path_1, "corr_V1_0.csv")).set_index("Class")
report_2 = pd.read_csv(os.path.join(data_path_2, "corr_RTK.csv")).set_index("Class")

# %%
df_n_1 = report_1[[col for col in report_1.columns if "Spearman_Coefficient" in col]].rename(index={'asphalt-concrete': 'asphalt', 'paving_stones-sett': 'paved'})
df_n_2 = report_2[[col for col in report_2.columns if "Spearman_Coefficient" in col]]

# %%
print(df_n_1)
print(df_n_2)
# Out:
#          42_Spearman_Coefficient  1024_Spearman_Coefficient  \
# Class
# asphalt                 0.201041                   0.274003
# paved                  -0.131257                  -0.093122
# unpaved                -0.133933                  -0.127584
# Overall                 0.245464                   0.177517
#
#          3_Spearman_Coefficient  57_Spearman_Coefficient  \
# Class
# asphalt                0.301464                 0.302448
# paved                 -0.053721                 0.052579
# unpaved               -0.213642                -0.183255
# Overall                0.016474                 0.272948
#
#          1000_Spearman_Coefficient
# Class
# asphalt                   0.170723
# paved                     0.002186
# unpaved                  -0.109928
# Overall                   0.085159
#          42_Spearman_Coefficient  1024_Spearman_Coefficient  \
# Class
# asphalt                 0.714299                   0.663755
# paved                   0.422293                   0.427906
# unpaved                 0.220707                   0.337959
# Overall                 0.621902                   0.465237
#
#          3_Spearman_Coefficient  57_Spearman_Coefficient  \
# Class
# asphalt                0.667484                 0.685252
# paved                  0.463240                 0.396396
# unpaved                0.390877                 0.495293
# Overall                0.482455                 0.595728
#
#          1000_Spearman_Coefficient
# Class
# asphalt                   0.677656
# paved                     0.454236
# unpaved                   0.144789
# Overall                   0.418722

# %% [markdown]
# ### Variance test

# %%
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    # print(n_1)
    # print(n_2)
    print(surface)
    f, p = f_test(n_1, n_2)
    print(f"F test statistic: {f}, p value: {p}")
    f, p = f_test(n_2, n_1)
    print(f"F test statistic: {f}, p value: {p}")
# Out:
# asphalt
# F test statistic: 9.07117152351407, p value: 0.027619589028191505
# F test statistic: 0.11023934421345956, p value: 0.9723804109718085
# paved
# F test statistic: 7.583245073430153, p value: 0.03755815357311576
# F test statistic: 0.13186966665547403, p value: 0.9624418464268841
# unpaved
# F test statistic: 0.09731499458976337, p value: 0.9778001030073022
# F test statistic: 10.275908704671403, p value: 0.022199896992697754
# Overall
# F test statistic: 1.5151934692465716, p value: 0.3485241017593743
# F test statistic: 0.6599817253022143, p value: 0.6514758982406257

# %% [markdown]
# ### Significance test

# %%
# T test
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    print(surface)
    t, p = stats.ttest_ind(n_1, n_2, equal_var=True, alternative="two-sided")
    print(f"T test statistic: {t}, p value: {p}")
    t, p = stats.ttest_ind(n_1, n_2, equal_var=True, alternative="two-sided")
    print(f"T test statistic: {t}, p value: {p}")
# Out:
# asphalt
# T test statistic: -15.136182247378247, p value: 3.5926050745354854e-07
# T test statistic: -15.136182247378247, p value: 3.5926050745354854e-07
# paved
# T test statistic: -13.663131938555424, p value: 7.928454106158421e-07
# T test statistic: -13.663131938555424, p value: 7.928454106158421e-07
# unpaved
# T test statistic: -7.274008097153627, p value: 8.60254578124228e-05
# T test statistic: -7.274008097153627, p value: 8.60254578124228e-05
# Overall
# T test statistic: -5.747111709434142, p value: 0.0004304195508509053
# T test statistic: -5.747111709434142, p value: 0.0004304195508509053

# %%
# Welch test
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    print(surface)
    t, p = stats.ttest_ind(n_1, n_2, equal_var=False, alternative="two-sided")
    print(f"T test statistic: {t}, p value: {p}")
    t, p = stats.ttest_ind(n_1, n_2, equal_var=False, alternative="two-sided")
    print(f"T test statistic: {t}, p value: {p}")
# Out:
# asphalt
# T test statistic: -15.136182247378247, p value: 2.7770711550145295e-05
# T test statistic: -15.136182247378247, p value: 2.7770711550145295e-05
# paved
# T test statistic: -13.663131938555424, p value: 3.573885684141629e-05
# T test statistic: -13.663131938555424, p value: 3.573885684141629e-05
# unpaved
# T test statistic: -7.274008097153627, p value: 0.0009352138410203934
# T test statistic: -7.274008097153627, p value: 0.0009352138410203934
# Overall
# T test statistic: -5.747111709434142, p value: 0.0005007195343149048
# T test statistic: -5.747111709434142, p value: 0.0005007195343149048

# %%
# Mann-Whitney U test
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    print(surface)
    u, p = stats.mannwhitneyu(n_1, n_2, alternative="two-sided")
    print(f"U test statistic: {u}, p value: {p}")
# Out:
# asphalt
# U test statistic: 0.0, p value: 0.007936507936507936
# paved
# U test statistic: 0.0, p value: 0.007936507936507936
# unpaved
# U test statistic: 0.0, p value: 0.007936507936507936
# Overall
# U test statistic: 0.0, p value: 0.007936507936507936

# %% [markdown]
# # Classification

# %%
report_1 = pd.read_csv(os.path.join(data_path_1, "classification_V1_0.csv")).set_index("Class")
report_2 = pd.read_csv(os.path.join(data_path_2, "classification_RTK.csv")).set_index("Class")
print(report_1)
print(report_2)
# Out:
#               42_precision  42_recall  42_f1-score   42_support  \
# Class
# asphalt           0.764398   0.947596     0.846195  4160.000000
# paved             0.814369   0.769585     0.791344  3255.000000
# unpaved           0.876106   0.106337     0.189655   931.000000
# accuracy          0.784328   0.784328     0.784328     0.784328
# macro avg         0.818291   0.607840     0.609065  8346.000000
# weighted avg      0.796348   0.784328     0.751566  8346.000000
#
#               1024_precision  1024_recall  1024_f1-score  1024_support  \
# Class
# asphalt             0.700614     0.987260       0.819597    4160.00000
# paved               0.956416     0.728111       0.826792    3255.00000
# unpaved             0.666667     0.004296       0.008538     931.00000
# accuracy            0.776540     0.776540       0.776540       0.77654
# macro avg           0.774566     0.573222       0.551642    8346.00000
# weighted avg        0.796592     0.776540       0.731929    8346.00000
#
#               3_precision  3_recall  3_f1-score    3_support  57_precision  \
# Class
# asphalt          0.675967  0.978365    0.799529  4160.000000      0.730978
# paved            0.819796  0.567435    0.670661  3255.000000      0.893476
# unpaved          0.833333  0.064447    0.119641   931.000000      0.831858
# accuracy         0.716151  0.716151    0.716151     0.716151      0.785167
# macro avg        0.776366  0.536749    0.529943  8346.000000      0.818771
# weighted avg     0.749616  0.716151    0.673427  8346.000000      0.805607
#
#               57_recall  57_f1-score   57_support  1000_precision  \
# Class
# asphalt        0.969952     0.833678  4160.000000        0.613033
# paved          0.744700     0.812332  3255.000000        0.955272
# unpaved        0.100967     0.180077   931.000000        0.704545
# accuracy       0.785167     0.785167     0.785167        0.677690
# macro avg      0.605206     0.608696  8346.000000        0.757617
# weighted avg   0.785167     0.752443  8346.000000        0.756717
#
#               1000_recall  1000_f1-score  1000_support
# Class
# asphalt          0.992788       0.758007    4160.00000
# paved            0.459293       0.620332    3255.00000
# unpaved          0.033298       0.063590     931.00000
# accuracy         0.677690       0.677690       0.67769
# macro avg        0.495126       0.480643    8346.00000
# weighted avg     0.677690       0.626850    8346.00000
#               42_precision  42_recall  42_f1-score   42_support  \
# Class
# asphalt           0.832731   0.913441     0.871221  3281.000000
# paved             0.995227   0.512600     0.676673  1627.000000
# unpaved           0.732796   0.981281     0.839027  1389.000000
# accuracy          0.824837   0.824837     0.824837     0.824837
# macro avg         0.853585   0.802441     0.795641  6297.000000
# weighted avg      0.852672   0.824837     0.813853  6297.000000
#
#               1024_precision  1024_recall  1024_f1-score  1024_support  \
# Class
# asphalt             0.704213     0.998476       0.825917   3281.000000
# paved               0.923940     0.455439       0.610128   1627.000000
# unpaved             0.990510     0.601152       0.748208   1389.000000
# accuracy            0.770526     0.770526       0.770526      0.770526
# macro avg           0.872888     0.685022       0.728084   6297.000000
# weighted avg        0.824137     0.770526       0.753021   6297.000000
#
#               3_precision  3_recall  3_f1-score    3_support  57_precision  \
# Class
# asphalt          0.880828  0.973179    0.924703  3281.000000      0.853029
# paved            0.829927  0.773817    0.800891  1627.000000      0.988683
# unpaved          0.934199  0.776818    0.848270  1389.000000      0.695452
# accuracy         0.878355  0.878355    0.878355     0.878355      0.824996
# macro avg        0.881651  0.841271    0.857955  6297.000000      0.845721
# weighted avg     0.879449  0.878355    0.875853  6297.000000      0.853320
#
#               57_recall  57_f1-score   57_support  1000_precision  \
# Class
# asphalt        0.875648     0.864190  3281.000000        0.861381
# paved          0.590658     0.739515  1627.000000        0.974050
# unpaved        0.979842     0.813509  1389.000000        0.889404
# accuracy       0.824996     0.824996     0.824996        0.887407
# macro avg      0.815382     0.805738  6297.000000        0.908278
# weighted avg   0.824996     0.820798  6297.000000        0.896673
#
#               1000_recall  1000_f1-score  1000_support
# Class
# asphalt          0.973484       0.914008   3281.000000
# paved            0.645974       0.776792   1627.000000
# unpaved          0.966883       0.926526   1389.000000
# accuracy         0.887407       0.887407      0.887407
# macro avg        0.862114       0.872442   6297.000000
# weighted avg     0.887407       0.881316   6297.000000

# %% [markdown]
# ## Precision

# %%
df_n_1 = report_1[[col for col in report_1.columns if "precision" in col]]
df_n_2 = report_2[[col for col in report_2.columns if "precision" in col]]

# Variance test
print("Precision: Variance test")
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    # print(n_1)
    # print(n_2)
    print(surface)
    f, p = f_test(n_1, n_2)
    print(f"F test statistic: {f}, p value: {p}")
    f, p = f_test(n_2, n_1)
    print(f"F test statistic: {f}, p value: {p}")

# T test
print("\nPrecision: T test")
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    print(surface)
    t, p = stats.ttest_ind(n_1, n_2, equal_var=True, alternative="two-sided")
    print(f"T test statistic: {t}, p value: {p}")

# Welch test
print("\nPrecision: Welch test")
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    print(surface)
    t, p = stats.ttest_ind(n_1, n_2, equal_var=False, alternative="two-sided")
    print(f"T test statistic: {t}, p value: {p}")

# Mann-Whitney U test
print("\nPrecision: Mann-Whitney U test")
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    print(surface)
    u, p = stats.mannwhitneyu(n_1, n_2, alternative="two-sided")
    print(f"U test statistic: {u}, p value: {p}")
# Out:
# Precision: Variance test
# asphalt
# F test statistic: 0.6646421936393029, p value: 0.6490504429110169
# F test statistic: 1.5045689388517722, p value: 0.3509495570889831
# paved
# F test statistic: 1.020296378327048, p value: 0.49246557495427434
# F test statistic: 0.9801073700170068, p value: 0.5075344250457257
# unpaved
# F test statistic: 0.5042268087954621, p value: 0.7382395073473631
# F test statistic: 1.9832344939946391, p value: 0.2617604926526369
# accuracy
# F test statistic: 1.0571033010241067, p value: 0.479186035396735
# F test statistic: 0.9459813426286856, p value: 0.520813964603265
# macro avg
# F test statistic: 1.2699030287491322, p value: 0.41124146346684953
# F test statistic: 0.7874617016899397, p value: 0.5887585365331506
# weighted avg
# F test statistic: 0.8577349136418722, p value: 0.5573226225430388
# F test statistic: 1.165861368233318, p value: 0.44267737745696123
#
# Precision: T test
# asphalt
# T test statistic: -3.1832832445154553, p value: 0.012933414951161674
# paved
# T test statistic: -1.2464639320295041, p value: 0.24785376626089725
# unpaved
# T test statistic: -0.9363737560002119, p value: 0.3764822975574411
# accuracy
# T test statistic: -2.9396513508084166, p value: 0.018719625293291995
# macro avg
# T test statistic: -5.007006779045993, p value: 0.0010436542784585878
# weighted avg
# T test statistic: -4.730783104643377, p value: 0.00148143133917386
#
# Precision: Welch test
# asphalt
# T test statistic: -3.183283244515455, p value: 0.013621780229682101
# paved
# T test statistic: -1.2464639320295043, p value: 0.24785719872617018
# unpaved
# T test statistic: -0.9363737560002119, p value: 0.3793522605024662
# accuracy
# T test statistic: -2.9396513508084166, p value: 0.018735403011678687
# macro avg
# T test statistic: -5.007006779045994, p value: 0.0010884863990051675
# weighted avg
# T test statistic: -4.730783104643377, p value: 0.0015053009537885932
#
# Precision: Mann-Whitney U test
# asphalt
# U test statistic: 2.0, p value: 0.031746031746031744
# paved
# U test statistic: 5.0, p value: 0.15079365079365079
# unpaved
# U test statistic: 7.0, p value: 0.30952380952380953
# accuracy
# U test statistic: 3.0, p value: 0.05555555555555555
# macro avg
# U test statistic: 0.0, p value: 0.007936507936507936
# weighted avg
# U test statistic: 0.0, p value: 0.007936507936507936

# %%
## Recall

# %%
df_n_1 = report_1[[col for col in report_1.columns if "recall" in col]]
df_n_2 = report_2[[col for col in report_2.columns if "recall" in col]]

# Variance test
print("Recall: Variance test")
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    # print(n_1)
    # print(n_2)
    print(surface)
    f, p = f_test(n_1, n_2)
    print(f"F test statistic: {f}, p value: {p}")
    f, p = f_test(n_2, n_1)
    print(f"F test statistic: {f}, p value: {p}")

# T test
print("\nRecall: T test")
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    print(surface)
    t, p = stats.ttest_ind(n_1, n_2, equal_var=True, alternative="two-sided")
    print(f"T test statistic: {t}, p value: {p}")

# Welch test
print("\nRecall: Welch test")
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    print(surface)
    t, p = stats.ttest_ind(n_1, n_2, equal_var=False, alternative="two-sided")
    print(f"T test statistic: {t}, p value: {p}")

# Mann-Whitney U test
print("\nRecall: Mann-Whitney U test")
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    print(surface)
    u, p = stats.mannwhitneyu(n_1, n_2, alternative="two-sided")
    print(f"U test statistic: {u}, p value: {p}")
# Out:
# Recall: Variance test
# asphalt
# F test statistic: 0.12232817403792688, p value: 0.9669499638749031
# F test statistic: 8.174731682743486, p value: 0.03305003612509694
# paved
# F test statistic: 1.1910339131456071, p value: 0.4347739994663029
# F test statistic: 0.8396066551614196, p value: 0.565226000533697
# unpaved
# F test statistic: 0.06680935059936757, p value: 0.9887254079026713
# F test statistic: 14.967964679026025, p value: 0.011274592097328728
# accuracy
# F test statistic: 1.0571033010241067, p value: 0.479186035396735
# F test statistic: 0.9459813426286856, p value: 0.520813964603265
# macro avg
# F test statistic: 0.48329799434103377, p value: 0.7506924751925295
# F test statistic: 2.0691168010400665, p value: 0.24930752480747054
# weighted avg
# F test statistic: 1.0571033010241067, p value: 0.479186035396735
# F test statistic: 0.9459813426286856, p value: 0.520813964603265
#
# Recall: T test
# asphalt
# T test statistic: 1.1817300974087206, p value: 0.2712466546308358
# paved
# T test statistic: 0.7118927317675928, p value: 0.4967632705640238
# unpaved
# T test statistic: -10.232091607890725, p value: 7.150045910267135e-06
# accuracy
# T test statistic: -2.9396513508084166, p value: 0.018719625293291995
# macro avg
# T test statistic: -6.327306760844086, p value: 0.0002260475169143237
# weighted avg
# T test statistic: -2.9396513508084166, p value: 0.018719625293291995
#
# Recall: Welch test
# asphalt
# T test statistic: 1.1817300974087206, p value: 0.29081001353399916
# paved
# T test statistic: 0.7118927317675928, p value: 0.49691283269443653
# unpaved
# T test statistic: -10.232091607890725, p value: 0.000265838881043809
# accuracy
# T test statistic: -2.9396513508084166, p value: 0.018735403011678687
# macro avg
# T test statistic: -6.327306760844086, p value: 0.00036423726057898857
# weighted avg
# T test statistic: -2.9396513508084166, p value: 0.018735403011678687
#
# Recall: Mann-Whitney U test
# asphalt
# U test statistic: 16.0, p value: 0.5476190476190477
# paved
# U test statistic: 15.0, p value: 0.6904761904761905
# unpaved
# U test statistic: 0.0, p value: 0.007936507936507936
# accuracy
# U test statistic: 3.0, p value: 0.05555555555555555
# macro avg
# U test statistic: 0.0, p value: 0.007936507936507936
# weighted avg
# U test statistic: 3.0, p value: 0.05555555555555555

# %% [markdown]
# ## F1 score

# %%
df_n_1 = report_1[[col for col in report_1.columns if "f1-score" in col]]
df_n_2 = report_2[[col for col in report_2.columns if "f1-score" in col]]

# Variance test
print("F1 score: Variance test")
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    # print(n_1)
    # print(n_2)
    print(surface)
    f, p = f_test(n_1, n_2)
    print(f"F test statistic: {f}, p value: {p}")
    f, p = f_test(n_2, n_1)
    print(f"F test statistic: {f}, p value: {p}")

# T test
print("\nF1 score: T test")
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    print(surface)
    t, p = stats.ttest_ind(n_1, n_2, equal_var=True, alternative="two-sided")
    print(f"T test statistic: {t}, p value: {p}")

# Welch test
print("\nF1 score: Welch test")
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    print(surface)
    t, p = stats.ttest_ind(n_1, n_2, equal_var=False, alternative="two-sided")
    print(f"T test statistic: {t}, p value: {p}")

# Mann-Whitney U test
print("\nF1 score: Mann-Whitney U test")
for surface in df_n_1.index:
    n_1 = df_n_1.loc[surface].values
    n_2 = df_n_2.loc[surface].values
    print(surface)
    u, p = stats.mannwhitneyu(n_1, n_2, alternative="two-sided")
    print(f"U test statistic: {u}, p value: {p}")
# Out:
# F1 score: Variance test
# asphalt
# F test statistic: 0.7438794374087068, p value: 0.6093592075006311
# F test statistic: 1.344303861232521, p value: 0.3906407924993689
# paved
# F test statistic: 1.4292063764602512, p value: 0.36886455742116375
# F test statistic: 0.699689013756518, p value: 0.6311354425788361
# unpaved
# F test statistic: 1.4350709541990645, p value: 0.3674243653533835
# F test statistic: 0.6968296564528516, p value: 0.6325756346466163
# accuracy
# F test statistic: 1.0571033010241067, p value: 0.479186035396735
# F test statistic: 0.9459813426286856, p value: 0.520813964603265
# macro avg
# F test statistic: 0.9127287027990264, p value: 0.5341961997855691
# F test statistic: 1.0956158132568226, p value: 0.4658038002144309
# weighted avg
# F test statistic: 1.1110534549487507, p value: 0.46058211610455335
# F test statistic: 0.9000467039150035, p value: 0.5394178838954466
#
# F1 score: T test
# asphalt
# T test statistic: -2.902687811783134, p value: 0.019809896687746978
# paved
# T test statistic: 0.43425499032237097, p value: 0.6755775981661365
# unpaved
# T test statistic: -16.09527208584283, p value: 2.2287861805412497e-07
# accuracy
# T test statistic: -2.9396513508084166, p value: 0.018719625293291995
# macro avg
# T test statistic: -7.228034289419465, p value: 8.99561784409863e-05
# weighted avg
# T test statistic: -3.5720300770453783, p value: 0.007272143833847104
#
# F1 score: Welch test
# asphalt
# T test statistic: -2.902687811783134, p value: 0.02026625252648157
# paved
# T test statistic: 0.43425499032237097, p value: 0.675927459344577
# unpaved
# T test statistic: -16.09527208584283, p value: 3.100629702687405e-07
# accuracy
# T test statistic: -2.9396513508084166, p value: 0.018735403011678687
# macro avg
# T test statistic: -7.228034289419465, p value: 9.089847881472014e-05
# weighted avg
# T test statistic: -3.5720300770453783, p value: 0.007305210848819232
#
# F1 score: Mann-Whitney U test
# asphalt
# U test statistic: 2.0, p value: 0.031746031746031744
# paved
# U test statistic: 16.0, p value: 0.5476190476190477
# unpaved
# U test statistic: 0.0, p value: 0.007936507936507936
# accuracy
# U test statistic: 3.0, p value: 0.05555555555555555
# macro avg
# U test statistic: 0.0, p value: 0.007936507936507936
# weighted avg
# U test statistic: 0.0, p value: 0.007936507936507936
